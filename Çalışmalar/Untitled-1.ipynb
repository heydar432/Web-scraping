# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
url = 'https://www.soccerstand.com/'
res = requests.get(url)
print(res)
content = res.text
soup = BeautifulSoup(content, 'lxml')
print(soup)
# Out:
# <Response [200]>
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=11" http-equiv="X-UA-Compatible"/>
# <title>Soccer Livescore - Live Scores &amp; Match Results - Soccerstand.com</title>
# <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://cdn.cookielaw.org/vendorlist/iab2Data.json" rel="preload"/>
# <noscript>
# <meta content="0;URL='https://www.flashscore.mobi/'" http-equiv="refresh"/>
# </noscript>
# <meta content="" name="keywords"/>
# <meta content="Visit Soccerstand.com for the fastest soccer livescore and results service. Get real-time livescore, stats, live odds and scores from all global matches and leagues!" name="description"/>
# ...
